# %%
import pandas as pd
# !pip install dwave-ocean-sdk

# %%
d = pd.read_table('DATA_M_N=10_LENGTH=200.txt', delimiter = " ")
d
# Out:
#    -2.049788935383748192e-02  3.440714667168387475e-02  \
# 0                   0.023754                 -0.018815
# 1                  -0.003535                 -0.039542
# 2                   0.010652                  0.002246
# 3                   0.014739                  0.027565
# 4                   0.028856                 -0.029601
# 5                   0.018384                  0.016596
# 6                   0.001252                 -0.052402
# 7                  -0.003610                  0.014734
# 8                   0.009211                 -0.014071
#
#    2.281614256517387057e-02  -1.058708254303212908e-02  \
# 0                  0.031129                  -0.025796
# 1                  0.016308                  -0.030277
# 2                  0.005797                   0.013285
# 3                  0.011616                  -0.042730
# 4                  0.031648                  -0.002785
# 5                  0.020825                  -0.013399
# ...
